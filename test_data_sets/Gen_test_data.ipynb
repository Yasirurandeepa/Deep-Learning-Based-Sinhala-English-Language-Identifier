# %%
import pandas as pd
import numpy as np
data = pd.read_csv('en.txt', sep=" ", header=None)
data.columns = ['word']
data['tag'] = 'en'
data
# Out:
#                   word tag
# 0                  the  en
# 1                   of  en
# 2                  and  en
# 3                   to  en
# 4                    a  en
# 5                   in  en
# 6                  for  en
# 7                   is  en
# 8                   on  en
# 9                 that  en
# 10                  by  en
# 11                this  en
# 12                with  en
# 13                   i  en
# 14                 you  en
# 15                  it  en
# 16                 not  en
# 17                  or  en
# 18                  be  en
# 19                 are  en
# 20                from  en
# 21                  at  en
# 22                  as  en
# 23                your  en
# 24                 all  en
# 25                have  en
# 26                 new  en
# 27                more  en
# 28                  an  en
# 29                 was  en
# ...                ...  ..
# 19970        contested  en
# 19971             coma  en
# 19972            husky  en
# 19973         conserve  en
# 19974            bland  en
# 19975       electrodes  en
# 19976             svcd  en
# 19977             cron  en
# 19978            darth  en
# 19979        abatement  en
# 19980           cramer  en
# 19981              yup  en
# 19982       originator  en
# 19983            ching  en
# 19984         whipping  en
# 19985         skipping  en
# 19986         melanoma  en
# 19987             thug  en
# 19988           routed  en
# 19989          rudolph  en
# 19990          abigail  en
# 19991     missionaries  en
# 19992         yugoslav  en
# 19993      householder  en
# 19994              occ  en
# 19995             cpan  en
# 19996         plotting  en
# 19997              yan  en
# 19998       succeeding  en
# 19999  bizjournalshire  en
#
# [20000 rows x 2 columns]

# %%
data2 = pd.read_csv('si.txt', sep=" ", header=None)
data2.columns = ['word']
data2['tag'] = 'si'
data2
# Out:
#                 word tag
# 0          අභිචෝදකයා  si
# 1              අංකනය  si
# 2               අංකන  si
# 3               අංකය  si
# 4          අංකාන්තරය  si
# 5              අංකිත  si
# 6           අංකුට්ටා  si
# 7            අංකුරමය  si
# 8             අංකුරය  si
# 9              අංකුර  si
# 10            අංකුසය  si
# 11             අංගණය  si
# 12              අංගණ  si
# 13             අංගනය  si
# 14           අංගමාරය  si
# 15              අංගය  si
# 16            අංගරාග  si
# 17          අංගසමතාව  si
# 18           අංගහාරය  si
# 19         අංගාරක්ෂක  si
# 20           අංගාරධර  si
# 21               අංග  si
# 22          අංඟුලිකා  si
# 23             අංජනම  si
# 24             අංශකය  si
# 25        අංශචිත්‍රය  si
# 26           අංශභාගය  si
# 27           අංශභාගී  si
# 28              අංශය  si
# 29             අංශික  si
# ...              ...  ..
# 24940         ෆෝටෝනය  si
# 24941        ෆෝමලින්  si
# 24942        ෆෝල්ඩරය  si
# 24943       ෆෲක්ටෝස්  si
# 24944        ප්‍රධාන  si
# 24945     ශුභාශිංසනය  si
# 24946         ශූන්‍ය  si
# 24947          ‍අඬුව  si
# 24948      ‍අහම්මානය  si
# 24949     ‍කුලීකාරයා  si
# 24950        ‍කෙනෙක්  si
# 24951          ‍ගදාව  si
# 24952        ‍ගල්ගොඩ  si
# 24953           ‍ගොඩ  si
# 24954           ‍ඝෝෂ  si
# 24955        ‍තෙතමනය  si
# 24956      ‍තෙරපෙනවා  si
# 24957        ‍තෝරනවා  si
# 24958        ‍බෙරයක්  si
# 24959       ‍බේරෙනවා  si
# 24960          ‍මෘදු  si
# 24961       ‍මෝස්තරය  si
# 24962         ‍යමින්  si
# 24963        ‍යෂ්ටිය  si
# 24964        ‍වේළනවා  si
# 24965     ‍සමාජවාදය‍  si
# 24966        ‍‍ටසාර්  si
# 24967         ‍‍ශෝකය  si
# 24968  ‍‍‍බේගල්කාරයා  si
# 24969        ‍‍‍‍‍කය  si
#
# [24970 rows x 2 columns]

# %%
final = pd.concat([data, data2], ignore_index=True)
final.to_excel('test_set.xlsx',index=False)
